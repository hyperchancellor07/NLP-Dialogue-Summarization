# %% [markdown]
# # Notebook 07: Pipeline Data Preparation
# - Execute data ingestion, validation, and transformation pipelines
# - Persist processed datasets for downstream evaluation and inference
# This notebook does NOT perform training or analysis.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -r /content/drive/MyDrive/ml_projects/NLP_Text_Summarization/requirements.txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 72.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 100.2 MB/s eta 0:00:00
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=eb64fc57977d7b10db3f4b9492e57a72b88145ff0b547b4e7266e550f2a36b30
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
# Successfully built rouge-score
# ...

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path("/content/drive/MyDrive/ml_projects/NLP_Text_Summarization/").resolve()
sys.path.append(str(PROJECT_ROOT))

# %%
from src.components.data_ingestion import DataIngestion

ingestion = DataIngestion(config_path="/content/drive/MyDrive/ml_projects/NLP_Text_Summarization/config/config.yaml")
dataset = ingestion.run()
# Out:
# 📁 Directory created at: /content/drive/MyDrive/ml_projects/NLP_Text_Summarization/artifacts/data/processed
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
from src.components.data_validation import DataValidation

validation = DataValidation(config_path="/content/drive/MyDrive/ml_projects/NLP_Text_Summarization/config/config.yaml")
validation.run(dataset)
# Out:
# 📁 Directory created at: /content/drive/MyDrive/ml_projects/NLP_Text_Summarization/artifacts/data/validation

# %%
from src.components.data_transformation import DataTransformation

transformation = DataTransformation(config_path="/content/drive/MyDrive/ml_projects/NLP_Text_Summarization/config/config.yaml")
transformation.run(dataset)
# Out:
# 📁 Directory created at: /content/drive/MyDrive/ml_projects/NLP_Text_Summarization/artifacts/tokenizer
# tokenizer_config.json:   0%|          | 0.00/88.0 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/1.91M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# ...
# Saving the dataset (0/1 shards):   0%|          | 0/819 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 14731
#     })
#     validation: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 818
#     })
#     test: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 819
#     })
# })
